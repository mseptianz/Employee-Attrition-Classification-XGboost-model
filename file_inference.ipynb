# %% [markdown]
# # Introduction
#
# Nama    : Muhammad Septian Zamzani
# <br>
# Batch   : HCK-21
# <br>
# Objective   : Create program that designed to predict the probability of employee attrition, offering valuable insights to help the HR team take proactive steps in retaining key talent. By leveraging advanced machine learning algorithms, it allows the company to identify potential risk factors leading to employee turnover.

# %% [markdown]
# # Import libraries

# %%
import pickle
import pandas as pd

# %% [markdown]
# # Import Model

# %%
# Load Files
with open('model.pkl', 'rb') as file_1:
  best_model = pickle.load(file_1)

# %% [markdown]
# # Input data inference

# %%
new_data = {
    'Employee_ID': [1001, 1002, 1003],
    'Age': [28, 45, 35],
    'Gender': ['Male', 'Female', 'Male'],
    'Years at Company': [3, 10, 7],
    'Job Role': ['Education', 'Media', 'Healthcare'],
    'Monthly Income': [7000, 12000, 9000],
    'Work-Life Balance': ['Excellent', 'Poor', 'Good'],
    'Job Satisfaction': ['High', 'Very High', 'Low'],
    'Performance Rating': ['Average', 'Low', 'High'],
    'Number of Promotions': [1, 2, 1],
    'Distance from Home': [15, 8, 20],
    'Education Level': ['Master’s Degree', 'Bachelor’s Degree', 'High School'],
    'Marital Status': ['Single', 'Married', 'Single'],
    'Job Level' : ['Entry', 'Mid', 'Senior'],
    'Company Size': ['Medium', 'Large', 'Small'],
    'Company Tenure': [30, 10, 17],
    'Number of Dependents' : [1,2,3],
    'Remote Work': ['Yes','No','No'],
    'Leadership Opportunities': ['Yes','No','No'],
    'Company Reputation': ['Excellent', 'Fair', 'Poor'],
    'Innovation Opportunities': ['No','Yes','No'],
    'Employee Recognition': ['Low', 'High', 'Very High'],
    }
data_inf = pd.DataFrame(new_data)   
data_inf
# Out:
#    Employee_ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         1001   28    Male                 3   Education            7000
# 1         1002   45  Female                10       Media           12000
# 2         1003   35    Male                 7  Healthcare            9000
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent             High            Average                     1
# 1              Poor        Very High                Low                     2
# 2              Good              Low               High                     1
#
#    ...  Marital Status Job Level Company Size Company Tenure  \
# 0  ...          Single     Entry       Medium             30
# 1  ...         Married       Mid        Large             10
# 2  ...          Single    Senior        Small             17
#
#   Number of Dependents  Remote Work  Leadership Opportunities  \
# ...

# %% [markdown]
# # Predict New Data

# %%
best_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('pipe_num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Years at Company',
#                                                    'Monthly Income',
#                                                    'Number of Promotions',
#                                                    'Distance from Home',
#                                                    'Company Tenure',
#                                                    'Number of Dependents']),
#                                                  ('pipe_cat_nominal',
#                                                   Pipeline(steps=[('nominal_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
best_model.predict(data_inf)
# Out:
# array([1, 0, 1])
